# %% [markdown]
# # Customer Churn – Main Plan
#
# ## 1 Business Understanding
#
# * Define churn clearly
# * Define business objective
# * Define success metric (business + ML)
#
# ---
#
# ## 2️ Data Understanding
#
# * Dataset overview
# * Feature types (numerical / categorical)
# * Target distribution (class imbalance)
# * Initial observations
#
# ---
#
# ## 3️ Data Cleaning
#
# * Handle missing values
# * Fix data types (TotalCharges issue)
# * Remove duplicates
# * Sanity checks
#
# ---
#
# ## 4️ Exploratory Data Analysis (EDA)
#
# * Target analysis
# * Numerical feature vs churn
# * Categorical feature vs churn
# * Correlation analysis
# * Key business insights
#
# ---
#
# ## 5️ Feature Engineering
#
# * Encoding categorical variables
# * Scaling numerical features
# * Handling imbalance (if required)
# * Optional feature creation
#
# ---
#
# ## 6️ Data Splitting Strategy
#
# * Train/Test split
# * Cross-validation strategy
# * Stratified split (important)
#
# ---
#
# ## 7️ Model Development
#
# * Baseline model (Logistic Regression)
# * Tree-based models (Random Forest, XGBoost)
# * Hyperparameter tuning
#
# ---
#
# ## 8️ Model Evaluation
#
# * Confusion Matrix
# * ROC-AUC
# * Precision / Recall / F1
# * Threshold tuning
# * Business impact analysis
#
# ---
#
# ## 9️ Model Selection
#
# * Compare models
# * Choose best based on objective
#
# ---
#
# ## 10 Model Serialization
#
# * Save preprocessing pipeline
# * Save trained model
# * Version control artifacts
#
# ---
#
# ## 11 Prediction Pipeline
#
# * Input schema
# * Data validation
# * Preprocessing
# * Prediction + probability output
#
# ---
#
# ## 12 Deployment
#
# * FastAPI / Streamlit
# * Docker (optional)
# * Basic monitoring plan
#
# ---
